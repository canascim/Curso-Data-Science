# %% [markdown]
# ## Exercício aula03(Modelo Relacional)

# %% [markdown]
# ## Exercícios
#
# ### Requisitos do cliente
#
# Uma escola de idiomas deseja automatizar seus processos.
#
# Essa escola oferece cursos, sendo que cada curso pode ser ministrado por apenas um professor.
#
# Os alunos podem se inscrever nos cursos e participar de mais de um curso ao mesmo tempo.
#
# A escola possui informações dos alunos, como RG, Nome, Endereço, Data de Nascimento, Idade, Gênero e Data da matrícula dos alunos.
#
# Os seguintes dados dos professores também devem ser armazenados: RG, Nome, Endereço, Data de Nascimento, Idade, Gênero, Disponibilidade, Habilidades e Data de admissão.
#
# Além disso, o sistema deve gerenciar o nome e a descrição do curso.
#
# Utilizando o MER criado no exercício do material anterior, responda as questões.
#
# ## Q1 Quais são os nomes das relações que fazem parte do modelo relacional desse sistema?
#
# Curso, Remoto, Presencial, Gravado, Ao Vivo, Acessa, Aluno, Pertence, Turma, AcontecePre, AconteceAV, Professor.
#
#
#
# ## Q2 Quais são os esquemas das relações encontradas? Faça uma descrição completa contendo detalhes sobre o domínio dos atributos. Indique quando eles não podem ser nulos.
#
# Relação Curso:
# Código: O campo código deve indicar o código único que identifica cada curso. Deve ser do tipo caracter, não pode ser nulo.
# Descrição: Descreve o curso em detalhes.Deve ser do tipo caracter, não pode ser nulo.
# Duração: Descreve a duração do curso em meses.  Deve ser numérico. Não pode ser nulo.
# Disciplina:  Descreve qual é a disciplina(idioma) do curso. Deve ser do tipo caracter, não pode ser nulo.
# Investimento: Descreve o valor do investimento a ser realizado pelo clinte no curso. Deve ser do tipo numérico, não pode ser nulao.
#
#
# Relação Remoto:
# Plataforma: Indica qual a plataforma de acesso ao curso. Deve ser do tipo caracter, não pode ser nulo.
# IDRemoto: identificação única para a relação remoto. Deve ser numérico. Não pode ser nulo.
#
# Relação Presencial:
# Local: Deve conter  o nome da unidade(filial). Deve ser do tipo caracter, não pode ser nulo.
# IDpresencial: identificação única para a relação Presencial. Deve ser numérico. Não pode ser nulo.
#
# Relação Gravado:
# IDGRAVADO: Deve conter a identificação única para a relação Gravado. Deve ser numérico. Não pode ser nulo.
#
# Relação Ao Vivo:
# IDAoVivo: Deve conter a identificação única para a relação Ao Vivo. Deve ser numérico. Não pode ser nulo.
#
# RElação Acessa:
# IDAcessa: Deve conter a identificação única para a relação Acessa. Deve ser numérico. Não pode ser nulo.
# Matrícula Aluno: Referencia o atributo matrícula do aluno na relação Aluno.  Deve ser numérico. Não pode ser nulo.
# IDGRAVADO: Referencia o atributo ID Gravado na relação Gravado. Deve ser numérico. Não pode ser nulo.
#
#
# Relação aluno:
# Matrícula: Número de registro de  Matrícula do aluno (RGM) na  escola. Não deve conter pontos. Deve ser numérico. Não pode ser nulo.
# CPF: CPF do aluno.Não deve conter pontos. Deve ser numérico. Não pode ser nulo.
# RG: RG do aluno.Não deve conter pontos. Deve ser numérico. Não pode ser nulo.
# nome: O nome do aluno deve ser insirido através dos campos 1.o nome, 2o nome, 3o nome.
# PNome:  Deve conter o primeiro nome do aluno. Deve ser do tipo caracter, não pode ser nulo.
# MNome: Deve conter o segundo nome do aluno. Deve ser do tipo caracter. Este campo é opcional, pode ser nulo.
# UNome: Deve conter o terceiro nome do aluno. Deve ser do tipo caracter, não pode ser nulo.
# Endereço: Este campo de conter o endereço do aluno.Deve ser do tipo caracter, não pode ser nulo.
# número: Deve conter o número do endereço. Deve ser do tipo númérico.  Pode ser nulo.
# Complemento: Complemento do endereço. Deve ser do tipo caracter, pode ser nulo.
# CEP: Deve conter o CEP do endereço do aluno.  Deve ser do tipo númérico. Não de ser nulo.
# Cidade: Este campo deve conter a cidade da residência do aluno. Deve ser do tipo caracter, não pode ser nulo.
# Estado: Este campo deve conter o estado da residência do aluno. Deve ser do tipo caracter, não pode ser nulo.
# Data de Nascimento: Deve conter a data de nascimento do aluno. Deve esar no  formato  de data. Nâo pode ser nulo.
# Idade: Este campo deve informar a idade do aluno. Deve ser numérico. Não pode ser nulo.
# Gênero: Este campo deve conter o sexo do aluno. Deve ser masculino ou feminio. Deve ser do tipo caracter, não pode ser nulo.
# Data de Matrícula: Este campo deve conter a data da matrícula. Deve esar no  formato  de data. Nâo pode ser nulo.
#
#
# Relação Pertence:
# IDPertence:  Deve conter a identificação única para a relação Pertence. Deve ser numérico. Não pode ser nulo.
# Matrícula do aluno: Referencia o atributo matrícula do aluno na relação Aluno.  Deve ser numérico. Não pode ser nulo.
# IDTURMA: Referencia o atributo turma da relação turma.  Deve ser numérico. Não pode ser nulo.
#
#
# Relação Turma:
# horário: Indica o horário de aula da turma. Deve estar no formato de hora. Não pode ser nulo.
# Dias de aula:Indica os dias de aula da turma. Deve ser do tipo caracter, não pode ser nulo.
# Turma: Identificão única da turma. Deve ser do tipo caracter, não pode ser nulo.
# IDPROFESSOR: Identificação única do professor. Deve ser numérico. Não pode ser nulo.
#
# Relação AcontecePre:
# IDPRE: Referencia o atributo IDPRE da relação Presencial.  Deve ser numérico. Não pode ser nulo.
# IDTURMA: Referencia o atributo turma da relação turma.  Deve ser numérico. Não pode ser nulo.
# ID ACONPRE: Deve conter a identificação única para a relação AcontecePre. Deve ser numérico. Não pode ser nulo.
#
#
# rELAÇÃO AconteceAV:
# IDAV: Referencia o atributo IDAV da relação Ao Vivo.  Deve ser numérico. Não pode ser nulo.
# IDTURMA: Referencia o atributo turma da relação turma.  Deve ser numérico. Não pode ser nulo.
# IDACONTAV:  Deve conter a identificação única para a relação AconteceAV. Deve ser numérico. Não pode ser nulo.
#
# relação:Professor:
# RG: RG do professor.Não deve conter pontos. Deve ser numérico. Não pode ser nulo.
# CPF: CPF do professor.Não deve conter pontos. Deve ser numérico. Não pode ser nulo.
# Data de Nascimento: Deve conter a data de nascimento do professor. Deve esar no  formato  de data. Nâo pode ser nulo.
# Idade: Este campo deve informar a idade do professor. Deve ser numérico. Não pode ser nulo.
# Gênero: Este campo deve conter o sexo do professor. Deve ser masculino ou feminio. Deve ser do tipo caracter, não pode ser nulo.
# Disponibilidade: Deve indicar a disponibilidade do professor para novas turmas. Seu valor deve ser sim ou não.Deve ser do tipo caracter, não pode ser nulo.
# salário: Deve indicar o valor do salário do professor. Deve ser do tipo numérico, não pode ser nulo.
# nome: O nome do professor deve ser insirido através dos campos 1.o nome, 2o nome, 3o nome.
# PNome:  Deve conter o primeiro nome do aluno. Deve ser do tipo caracter, não pode ser nulo.
# MNome: Deve conter o segundo nome do aluno. Deve ser do tipo caracter. Este campo é opcional, pode ser nulo.
# UNome: Deve conter o terceiro nome do aluno. Deve ser do tipo caracter, não pode ser nulo.
# habilidades: Deve indicar as habilidades do professor. Disciplinas que domina, habilidades interpessoais, etc.Deve ser do tipo caracter, não pode ser nulo.
# Endereço: Este campo de conter o endereço do professor.Deve ser do tipo caracter, não pode ser nulo.
# número: Deve conter o número do endereço. Deve ser do tipo númérico.  Pode ser nulo.
# Complemento: Complemento do endereço. Deve ser do tipo caracter, pode ser nulo.
# CEP: Deve conter o CEP do endereço do professor.  Deve ser do tipo númérico. Não de ser nulo.
# Cidade: Este campo deve conter a cidade da residência do professor. Deve ser do tipo caracter, não pode ser nulo.
# Estado: Este campo deve conter o estado da residência do professor. Deve ser do tipo caracter, não pode ser nulo.
# ID PROF: Deve identificar o ID do professor. Deve ser numérico. Não pode ser nulo.
#
#
# ## Q3 Quais são as chaves primárias?
# Curso: código
# Remoto: IDREMOTO
# Presencial: IDPRESENCIAL
# Gravado: IDGravado
# AoVivo: IDAoVivo
# Acessa: IDAcessa
# Aluno: Matrícula do Aluno
# Pertence: IDPertence
# Turma: Turma
# AcontecePre: IDACONPRE
# AConteceAV: IDACONAV
# Professor: IDPROF
#
# ## Q4 Represente a integridade referencial entre as relações encontradas.
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import datetime as dt
pd.options.display.max_columns = 35 #para aumentar a quantidade de colunas a serem visualizadas

# %%
dataframe_cadastro = pd.read_csv('https://raw.githubusercontent.com/renatapink/DSdegree/master/Modulo2/Mini_projeto1/cadastro.csv')
df_cadastro = dataframe_cadastro.copy()

dataframe_inv_p1 = pd.read_csv('https://raw.githubusercontent.com/renatapink/DSdegree/master/Modulo2/Mini_projeto1/investimento_parte1.csv')
df_inv_p1 = dataframe_inv_p1.copy()

dataframe_inv_p2 = pd.read_csv('https://raw.githubusercontent.com/renatapink/DSdegree/master/Modulo2/Mini_projeto1/investimento_parte2.csv')
df_inv_p2 = dataframe_inv_p2.copy()

# %%
df_cadastro
# Out:
#               id                                Nome  Sexo        Nasc  Idade  \
# 0      id0000001               Eunice Hellen do Vale   Fem  1970-11-12     51
# 1      id0000002     Sebastião Castelo Branco Júnior  Masc  2019-12-10      2
# 2      id0000003           Romildo Fábio de Carvalho  Masc  2015-12-28      6
# 3      id0000004           Lana Albina de Lemos Mumy   Fem  1993-05-03     28
# 4      id0000005    Rose Elisângela Vyrnium de Moura   Fem  1984-06-10     37
# ...          ...                                 ...   ...         ...    ...
# 38749  id0038750     Beatriz Maísa de Miranda Milani   Fem  1999-02-20     22
# 38750  id0038751                     Juan dos Santos  Masc  1999-07-10     22
# 38751  id0038752       Severino Edson de Viana Loase  Masc  1981-12-01     40
# 38752  id0038753                          Kim Mooshi  Masc  1999-12-06     22
# 38753  id0038754  Vinícius Arnaldo de Pereira Mendes  Masc  2003-09-13     18
#
# ...

# %%
def sexo():
    df_cadastro.replace('Masc', 'Masculino', inplace=True)
    df_cadastro.replace('Fem', 'Feminino', inplace=True)
    return df_cadastro
    
    
df_cadastro['Sexo'].map(sexo)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20132/1555073861.py in <module>
#       5
#       6
# ----> 7 df_cadastro['Sexo'].map(sexo)
#
# ~\anaconda3\envs\modulo2\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    4158         dtype: object
#    4159         """
# -> 4160         new_values = super()._map_values(arg, na_action=na_action)
#    4161         return self._constructor(new_values, index=self.index).__finalize__(
#    4162             self, method="map"
#
# ~\anaconda3\envs\modulo2\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     868
#     869         # mapper is a function
# --> 870         new_values = map_f(values, mapper)
#     871
#     872         return new_values
#
# ~\anaconda3\envs\modulo2\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
df_inv_p2
# Out:
#               id    Salario       Perfil  Ativo01  Ativo02  Ativo03   Ativo04  \
# 0      id0000859  $51483.81    Agressivo  1273.95  5080.37  3565.44       NaN
# 1      id0022202    $457.43  Conservador  1121.09  4927.51  3911.58   5511.70
# 2      id0002056  $93245.46     Moderado      NaN  5283.71  2914.76       NaN
# 3      id0005674   $3044.00    Agressivo  1353.76  5827.28  2998.24  16341.70
# 4      id0004777    $880.30    Agressivo      NaN  5695.77  3525.98       NaN
# ...          ...        ...          ...      ...      ...      ...       ...
# 24047  id0018222    $615.87  Conservador   933.65  5741.80  4031.59   6336.84
# 24048  id0005515    $212.76  Conservador  1624.80      NaN  2689.68  21886.01
# 24049  id0009893      $9.32    Agressivo   829.20      NaN  3831.45       NaN
# 24050  id0016100  $81796.74  Conservador  1587.47  4881.66  4352.03  10391.18
# 24051  id0027880  $38480.37    Agressivo   996.90  5604.43  2801.04   9183.62
#
# ...
